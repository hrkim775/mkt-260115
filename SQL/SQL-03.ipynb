# %%
# !pip install pymysql

# %%
import pymysql

db = pymysql.connect(
    host="127.0.0.1", # 또는 host="localhost"
    port=3306,
    user="root",
    passwd="ksdir8558",
    db="ecommerce",
    charset="utf8mb4"
)

db

# %%
# 정상적으로 파이썬 & mysql이 연결
# cursor() 매서드를 호출 -> mysql db안에 값을 전송해주는 역할

ecommerce = db.cursor()

ecommerce

# %%
# 테이블 생성

sql = """
    CREATE TABLE prodect (
    product_code VARCHAR(20) NOT NULL PRIMARY KEY,
    title VARCHAR(200) NOT NULL,
    ori_price INT,
    dis_price INT,
    dis_percent INT,
    delivery VARCHAR(2)
    );

"""

# %%
sql
# Out:
# '\n    CREATE TABLE prodect (\n    product_code VARCHAR(20) NOT NULL PRIMARY KEY,\n    title VARCHAR(200) NOT NULL,\n    ori_price INT,\n    dis_price INT,\n    dis_percent INT,\n    delivery VARCHAR(2)\n    );\n\n'

# %%
ecommerce.execute(sql)
# Out:
# 0

# %%
db.commit()

# %%
db.close()

# db를 연결한 후 close를 하면 오픈되어있던 db가 종료된다
# 만약 다시 동일한 db안에 접속을 하려면 다시 db를 connect 해야한다

# %%
# 테이블 안에 값을 추가

for index in range(10):
    product_code = 215673140 + index + 1

    SQL = """
    INSERT INTO prodect VALUES("""+str(product_code) +"""', 
    '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
    );
    """

    print(SQL)
# Out:
#     INSERT INTO prodect VALUES(215673141',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673142',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673143',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673144',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673145',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673146',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673147',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
#     INSERT INTO prodect VALUES(215673148',
#     '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
#     );
#
#
# ...

# %%
cursor =  db.cursor()

# %%
for index in range(10):
    product_code = 215673140 + index + 1

    SQL = F"""
    INSERT INTO prodect VALUES('{product_code}', 
    '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', '23000', 6900, 70, 'F'
    );
    """

    cursor.execute(SQL)

db.commit()

db.close()

# %%
cursor = db.cursor()

SQL = "SELECT * FROM prodect;"
cursor.execute(SQL)

# row = cursor.fetchone()
row = cursor.fetchmany(2)
print(row)

row = cursor.fetchone()
print(row)

# db.close()
# Out:
# ('215673141', '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
# ('215673142', '스위트바니 여름신상 5900원~롱원피스티셔츠/긴팔/반팔', 23000, 6900, 70, 'F')
