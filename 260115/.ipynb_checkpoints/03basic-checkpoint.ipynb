# %% [markdown]
# # 데이터 자료구조 1 - 리스트(list) (매우중요함)
# - 문자열, 정수, 실수, 논리형 -> (변수 : 값) // 300개의 값이 필요하다면 변수도 300개가 필요함
# - 변수 : 여러가지의 값을 그룹
#       - 공통분모를 가지고 있는 값을의 모임 -> 특성 분류
#       - 상대적으로 컴퓨터 메모리 공간 효율적 사용
#       - 대부분의 크롤링한 결과값 -> 리스트 형태의 자료구조로 값이 결정
#
# - 변수명 = [값, 값, 값] (대괄호가 나왔다? 리스트라고 생각해)
# - 리스트 & 문자열 : 유사성을 띄고 있다 -> 비슷한 문법 구조
# - 리스트 & 문자열 -> "공통속성"을 가지고 있기 때문에 위와 같은 이야기가 나오는 것임!
# - __iter__ -> iterale : 반복할 수 있는 / index
#
# - 값을 추가하는 방법
#     - append() : 리스트에 값을 추가 (뒤에서부터)
#     - 리스트 + 리스트 연산
#     - insert(추가하고자 하는 인덱스, 넣고자하는 값)
#     - extend(여러개의 값을 한번에 넣고자 할 때)
#
# - 값을 제거하는 방법
#     - pop() : 리스트에 값을 제거 (뒤에서부터) / -> 인자값으로 인덱스값 부여 -> 해당 인덱스의 값이 제거
#     - remove() : 리스트에서 특정 값을 직접 선택해서 제거
#     - del 리스트명[인덱스] : 해당 인덱스의 값을 제거 (많이 쓰이진 않는다)
#
# - 슬라이싱 기능 = 문자열과 동일 작동
# - 리스트 자료구조 안에 입력될 값의 타입이 상이해도 가능!

# %%
location = ["서울시", "경기도", "인천시"]
print(location)
# print(type(location))

print(location[0]) 
print(location[1])
print(location[2])
print(location[-1])
# Out:
# ['서울시', '경기도', '인천시']
# 서울시
# 경기도
# 인천시
# 인천시

# %%
text = "apple"
print(type(text))
# Out:
# <class 'str'>

# %%
print(dir(location))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
print(dir(text))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
location.append("부산시") # 인덱스를 지정할 수 없음 / 무조건 뒤에서부터
location
# Out:
# ['서울시', '경기도', '인천시', '부산시']

# %%
# 그렇가면 앞에서부터는 값을 넣을 수 없을까요 ? -> 없음
# 대신에 원하는 위치에 값을 넣을 수 있는 요소는 있음

# %%
a = [3, 4, 5]
b = [1, 2]

result = b + a
result.insert(0,0)

print(result)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
a = [1, 2, 3]

a.append([4, 5])
print(a[3][0])
# Out:
# 4

# %%
a = [1, 2, 3]

a.extend([4, 5])
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
location
# Out:
# ['서울시', '경기도', '인천시', '부산시']

# %%
location.pop()
# Out:
# '부산시'

# %%
location.pop(1) # 인덱스에 값을 넣으면 그 부분 적용 가능 / append와 차이점
# Out:
# '경기도'

# %%
location.append("부산시")

# %%
location.remove("부산시")

# %%
location.extend(["경기도", "부산시"])

# %%
location
# Out:
# ['서울시', '인천시', '부산시']

# %%
location[1:3]
# Out:
# ['인천시', '부산시']

# %%
location = ["서울시", "인천시", "경기도", "부산시"]

del location[0]

# %%
print(location)
# Out:
# ['인천시', '경기도', '부산시']

# %%
var = [1, 2, 3]
# 리스트를 선언함과 동시에 값을 할당

var01 = list()
# 리스트 안에 있는 값을 추가, 삭제 개별함수 존재
# 리스트 형태의 변수를 우선 선언 후 향후 추가, 삭제 가능!!!

print(type(var))
print(type(var01))
# Out:
# <class 'list'>
# <class 'list'>

# %%
var02 = [1, 2, "hello", True, [3, 4]]
print(var02)
# Out:
# [1, 2, 'hello', True, [3, 4]]
