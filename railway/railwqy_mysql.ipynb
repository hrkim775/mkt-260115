# %%
from sqlalchemy import create_engine
import pandas as pd

HOST = "yamanote.proxy.rlwy.net"
PORT = 23034
USER = "root"
PASSWORD = "VOwKZUmBoWMdIazWzXEtGCMCUAXGLWiP"
DATABASE = "railway"

engine = create_engine(
    f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
)

query = """ 
SELECT *
FROM brands01;
"""

df = pd.read_sql(query, engine)
df
# Out:
#    brand_id brand_name
# 0         2    ADDIDAS
# 1         3    MUSINSA
# 2         1       NIKE
