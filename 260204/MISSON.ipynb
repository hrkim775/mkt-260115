# %% [markdown]
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.common.by import By
# from webdriver_manager.chrome import ChromeDriverManager
# import time
#
# # 상수값으로서의 변수 목록
# URL = "https://search.11st.co.kr/pc/total-search?kwd=%25EC%25BA%25A0%25ED%2595%2591%25EC%259A%25A9%25ED%2592%2588&tabId=TOTAL_SEARCH"
#
# service = Service(ChromeDriverManager().install())
# options = Options()
#
# # options.add_argument("--headless")
# # options.add_argument("--disable-gpu")
# options.add_argument("--disable-dev-shm-usage")
# options.add_argument("--window-size=1920,1080")
# options.add_argument("--start-maximized")
# options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
# options.add_argument("--lang=ko_KR")
# options.add_argument("--no-sandbox")
#
# driver = webdriver.Chrome(service=service, options=options)
# driver.get(URL)
#
# # driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
# time.sleep(3)
#
# titles = driver.find_elements(By.CSS_SELECTOR, "div.c-card-item.c-card-item--list c-card-item__name dd")
# # titles = driver.find_element(By.CSS_SELECTOR, "div.c-card-item__name")
#
#
#
# for title in titles :
#     print(title.text)
#     # print(title.get_attribute("c-card-item__name"))
#
#
# driver.quit()

# %%
# 인터파크 -> 티켓 -> 뮤지컬 -> 뮤지컬 둘러보기 -> 공연명 / 공연장 / 공연기간 20개 크롤링

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://nol.interpark.com/"

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

# target_btn = driver.find_element(By.CSS_SELECTOR, "._service-link_1wxu7_25")
target_btn = driver.find_element(By.TAG_NAME, "a")
target_btn.click()
time.sleep(2)

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[9], line 28
#      26 # target_btn = driver.find_element(By.CSS_SELECTOR, "._service-link_1wxu7_25")
#      27 target_btn = driver.find_element(By.TAG_NAME, "a")
# ---> 28 target_btn.click()
#      29 time.sleep(2)
#      31 driver.quit()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:120, in WebElement.click(self)
#     112 def click(self) -> None:
#     113     """Clicks the element.
#     114
#     115     Example:
#    (...)
#     118     >>> element.click()
#     119     """
# --> 120     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:573, in WebElement._execute(self, command, params)
#     571     params = {}
#     572 params["id"] = self._id
# --> 573 return self._parent.execute(command, params)
#
# ...
