# %% [markdown]
# selenium을 활용한 crawling 미션
# https://www.gsshop.com/ 방문 후 TV편성표 방문
# 홈쇼핑 방송 시간 + 방송상품명 을 크롤링하기

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time


service = Service(ChromeDriverManager().install())


options = Options()
# options.add_argument("--headless") 
# options.add_argument("--disable-gpu") 
options.add_argument("--disable-dev-shm-usage") 
options.add_argument("--window-size=1920,1080") 
options.add_argument("--start-maximized") 
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-sandbox") 


driver = webdriver.Chrome(service=service, options=options) 
driver.get("https://www.gsshop.com/index.gs") 
time.sleep(3)

target_butten = driver.find_element(By.ID, "tvScheduleMain")
target_butten.click()
time.sleep(3)

#gs_data = []

items = driver.find_elements(By.CSS_SELECTOR, "article.items")
#for item in items :
#    print(item.text)
#    print(get_attribute("times")).text().split()
#    print(get_attribute("prd-name")).text().split()

for item in items :
    try :    
        broadcast_time = item.find_element(By.CSS_SELECTOR, "span.times").text().strip()
        broadcast_name = item.find_element(By.CSS_SELECTOR, ".saveLatestPrdLocation('1101748451','broadPrd');").text().strip()
#        gs_data.append({"방송시간": broadcast_time, "방송상품명": broadcast_name})
        print(item.text)

    except Exception as e :
        print("데이터 크롤링 실패 :", e)
        continue


driver.quit()
# Out:
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# 데이터 크롤링 실패 : 'str' object is not callable
# ...

# %% [markdown]
# selenium을 활용한 crawling 미션
#
# https://www.ssg.com/
# https://shinsegaemall.ssg.com/
# https://shinsegaemall.ssg.com/page/pc/happybuy.ssg
# https://shinsegaemall.ssg.com/page/pc/happybuy.ssg?trackingId=6000083344
# 50개 상품 : 상품명 + 판매금액 + 할인률 + URL

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
import time


service = Service(ChromeDriverManager().install())


options = Options()
# options.add_argument("--headless") 
# options.add_argument("--disable-gpu") 
options.add_argument("--disable-dev-shm-usage") 
options.add_argument("--window-size=1920,1080") 
options.add_argument("--start-maximized") 
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR") 
options.add_argument("--no-sandbox") 


driver = webdriver.Chrome(service=service, options=options) 
driver.get("https://www.ssg.com/") 
time.sleep(2)

mall_butten = driver.find_element(By.CSS_SELECTOR, ".gnb_mall_link[href='https://shinsegaemall.ssg.com']")
mall_butten.click()
time.sleep(2)

menu_butten = driver.find_element(By.CSS_SELECTOR, "li.menu_item")
menu_butten.click()
time.sleep(2)

food_butten = driver.find_element(By.CSS_SELECTOR, ".tabs-:Rcledaal6nj6:--tab-8")
food_butten.click()
time.sleep(2)

# driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")



driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[21], line 35
#      32 menu_butten.click()
#      33 time.sleep(2)
# ---> 35 food_butten = driver.find_element(By.CSS_SELECTOR, ".tabs-:Rcledaal6nj6:--tab-8")
#      36 food_butten.click()
#      37 time.sleep(2)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:922, in WebDriver.find_element(self, by, value)
#     919         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     920     return elements[0]
# --> 922 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.execute(self, driver_command, params)
#     451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
# ...
