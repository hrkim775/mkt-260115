# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://moolix.netlify.app/"

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

title = driver.find_element(By.XPATH, "//h2").text
date_and_rating = driver.find_element(By.XPATH, "//div[contains(@class, 'muted')]").text
date_text = date_and_rating.split(".")[0].strip()

# info = driver.find_element(By.XPATH, "(//div[contains(@class, 'stack')]/div)[1]").text
# info = driver.find_element(By.XPATH, "//div[contains(@class, 'stack')]/div/following-sibling::div[1]").text
                         
print("영화제목 : ", title)
print("개봉연도 : ", date_text)
# print("줄거리 : ", info)


# element = driver.find_element(By.XPATH, "//*[@id='q']")
# print(element)

# s_input = driver.find_element(By.XPATH, "//input[@placeholder='영화 검색 (제목)']")
# print("검색창 placeholder", s_input.get_attribute("placeholder"))

# titles = driver.find_elements(By.XPATH, "//div[@class='title']")  # 첫번째 방법
# titles = driver.find_elements(By.XPATH, "//section/article[@class='card']//div[@class='title']")  # 두번째 방법
# titles = driver.find_elements(By.XPATH, "//section/article[@class='card']//div[contains(@class, 'title')]")  # 세번째 방법
# elements = driver.find_elements(By.XPATH, "//img[@class='src']") # 이건 왜 안되지?


# posters = driver.find_elements(By.XPATH, "//img")
# posters = driver.find_elements(By.XPATH, "//article[contains(@class, 'card')]//img")

# for image in posters :
#     print(image.get_attribute("src"))


# movie_cards = driver.find_elements(By.XPATH, "//article[contains(@class, 'card')]")
# movie_cards[0].click() # 리스트 안에서 숫자를 세는거라 0번째
# time.sleep(3)

                                
# for element in elements : 
#     print(element.text)

driver.quit()
# Out:
# 영화제목 :
# 개봉연도 :
