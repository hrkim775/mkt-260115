# %% [markdown]
# [오늘의 미션] 2/27
#
# wconcept > best > 크롤링 [어떤 값을 크롤링 해와야 할 것인가? 고민]
# 크롤링 데이터 MySQL 전송
# MySQL 전송된 데이터를 가지고 다음과 같은 결과를 출력 (SQL 문법 활용)
#
# 판매가 기준 상위 20개 상품 조회
# 할인율이 30% 이상인 상품 조회 & 내림차순 정렬
# 특정 브랜드 (임의) 상품만 조회, 판매가 기준 오름차순 정렬
# 리뷰수가 100이상인 상품의 평균 판매가 조회
# 브랜드별 상품수 & 평균할인률 구하고 상품수가 많은 브랜드 10개 조회

# %% [markdown]
# 1. wconcept 사이트에 접속한다
# 2. 메인페이지에서 상단에 베스트 카테고리 버튼을 누른다
# - XPATH나 CSS_SELECT로 가져올수 있는데, 홈페이지 상으로는 CSS_SELECT가능할듯
#
# 3. 들어왔다면, 베스트 의류의 데이터를 확인한다 (총 200개)
# 4. 브랜드명, 제품명, 상품가격, 할인률, 할인가격, 리뷰수를 크롤링한다
# - 먼저 수집할 데이터를 모두 포함하고 있는 큰 영역을 선택하고 (XPATH나 CSS_SELECT로)
# - for in문과 try문을 활용한다
# - 수집할 데이터 각각을 확인하고 알맞은 방법을 선택한다
#
# 5. 브랜드명은 CSS_SELECT
# 6. 제품명은 CSS_SELECT
# 7. 상품가격은 CSS_SELECT
# 8. 할인률은 CSS_SELECT
# 9. 할인가격은 CSS_SELECT
# 10. 리뷰수는 CSS_SELECT (모두 CSS_SELECT로 가능할 것 처럼 보임)
# 11. 수집된 데이터를 MySQL로 가져온다
# -  wconcept db를 생성한다
# -  데이터가 들어갈 테이블을 생성한다
# -  들어갈 데이터에 맞게 각각의 컬럼을 생성한다
#
# 12. 가져온 데이터를 MySQL에서 확인한다
# 13. 판매가 기준 상위 20개 상품 조회
# - 판매가를 기준으로 WHERE절 사용
#
# 14. 할인율이 30% 이상인 상품 조회 & 내림차순 정렬
# - 할인율을 기준으로 >= 30% 의 조건을 걸고 ORDER BY DESC로 정렬
#
# 15. 특정 브랜드 (임의) 상품만 조회, 판매가 기준 오름차순 정렬
# - 브랜드 이름으로 조건을 걸고 상품을 조회 (기본이 오름차순이기 때문에 그냥 둬도 됨)
#
# 16. 리뷰수가 100이상인 상품의 평균 판매가 조회
# - 리뷰수를 기준으로 >= 100의 조건을 걸고 AVG를 사용해 평균 판매가를 조회
#
# 17. 브랜드별 상품수 & 평균할인률 구하고 상품수가 많은 브랜드 10개 조회
# - 브랜드로 그룹을 한다 GROUP BY
# - 상품수 & 평균할인률을 구한다
# - 데이터를 구했다면 HAVING절로 TOP10개의 조건을 줘서 값을 구한다

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
import csv

URL = "https://display.wconcept.co.kr"

service = Service(ChromeDriverManager().install())
options = Options()

options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(3)

best = driver.find_element(By.CSS_SELECTOR, ".sc-d57aa1fb-0.iXIzbJ.btn.area-click") 
best.click()
time.sleep(3)

driver.quit()
