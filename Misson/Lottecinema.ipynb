# %%
1. 롯데시네마 홈페이지에 들어간다
2. 메인페이지에서 영화라는 버튼을 클릭한다
3. 버튼을 클릭해서 영화 페이지 안에 들어갔다면 현재 상영작 TOP 5의 더보기 버튼을 누른다
4. 실행이 잘 되었다면 현재상영작 TOP 10 영화의 영화제목, 개봉일, 관람시간, 관람등급, 관람객수, 장르, 감독, 출연진 까지의 데이터를 크롤링한다
5. 수집된 데이터를 mysql로 저장한다

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

URL = "https://www.lottecinema.co.kr/NLCHS"

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--window-size=1920,1080")
options.add_argument("--start-maximized")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=service, options=options)
driver.get(URL)
time.sleep(2)

search_butten = driver.find_element(By.CSS_SELECTOR, "li > a[href='https://www.lottecinema.co.kr/NLCHS/Movie']")
search_butten.click()
time.sleep(2)

search_butten = driver.find_element(By.CSS_SELECTOR, "a.btn_txt_more.ty2")
search_butten.click()
time.sleep(2)

search_butten = driver.find_element(By.CSS_SELECTOR, "a.btn_col3.ty3")
search_butten.click()
time.sleep(2)

# product_data = []

products = driver.find_elements(By.CSS_SELECTOR, "div.movie_screen_box")[:10]

    for product in products :
        try :
            title = product.find_element(By.CSS_SELECTOR, "div.tit_info").text.strip()
        #     date = product.find_element(By.XPATH, "//span[contain(@class, 'roboto') and contains(text(), '신세계몰')]").text.strip()
        #     time = product.find_element(By.CSS_SELECTOR, "span.time")
        #     grade = product.find_element(By.CSS_SELECTOR, "span.grade_txt gr_12").text.strip()
        #     show = product.find_element(By.CSS_SELECTOR, "span.roboto").text.strip()
        #     gan = product.find_element(By.CSS_SELECTOR, "span.grade_txt gr_12").text.strip()
        #     director = product.find_element(By.CSS_SELECTOR, "span.grade_txt gr_12").text.strip()
        #     lineup = product.find_element(By.CSS_SELECTOR, "span.grade_txt gr_12").text.strip()

            
        #     product_data.append({"브랜드명": brand, "상품명": name, "URL": url, "평점": review_rating, "리뷰수": review_count})
        except Exception as e :
            print("데이터 크롤링 실패 :", e)
            continue

driver.quit()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0ee9656fc2e8ecd8399652ed7288795e", element="f.CB63D9A2CA6C13CB1AEE10E06213B651.d.99821D9B41560B449987C003F56A8EC0.e.7915")>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 38
#      35 # movie_data = []
#      37 products = driver.find_elements(By.CSS_SELECTOR, "div.movie_screen_box")[:10]
# ---> 38 print(products).text
#      40     # for product in products :
#      41     #     try :
#      42     #         product_info = product.find_element(By.CSS_SELECTOR, "div.sc-itBLYH.cDYUnS")
#    (...)
#      53     #         print("데이터 크롤링 실패 :", e)
#      54     #         continue
#      56 driver.quit()
#
# AttributeError: 'NoneType' object has no attribute 'text'
