# %%
import json

data = '{"id": "01", "language": "java", "edition": "third", "author": "David Park"}'
jsondata = json.loads(data)
print(type(jsondata), jsondata, jsondata["id"], jsondata["language"])
# Out:
# <class 'dict'> {'id': '01', 'language': 'java', 'edition': 'third', 'author': 'David Park'} 01 java

# %%
import json

data = {"id": "01", "language": "java", "edition": "third", "author": "David Park"}
jsondata = json.dumps(data)
print(type(jsondata),jsondata) # 문자열이기 때문에 []표기법은 쓸 수 없다
# Out:
# <class 'str'> {"id": "01", "language": "java", "edition": "third", "author": "David Park"}

# %%
import json

data = {"id": "01", "language": "python", "edition": "third", "author": "David Park"}

with open("00_data/test01.json", "w", encoding="utf-8-sig") as json_file :
    json_string = json.dump(data, json_file, indent=2)

# %%
import json

with open("00_data/US_category_id.json", "r", encoding="utf-8-sig") as json_file :
    json_data = json.load(json_file)
    for item in json_data['items'] :
        print(item['kind'])
# Out:
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
# youtube#videoCategory
