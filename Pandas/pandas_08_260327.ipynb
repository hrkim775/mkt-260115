# %%
import pandas as pd

# 데이터프레임을 만드는 방법.여러 시리즈가 있기 때문에 필드명을 써줘야한다
df = pd.DataFrame({
    "미국": [2.1, 2.2, 2.3],     
    "한국": [0.4, 0.5, 0.45],     
    "중국": [10, 13, 15]     
})

# 지금까지 파이썬에서는 {} 딕셔러니, [] 리스트라고 했지만, pnadas에서는 다르다

# %%
df
# Out:
#     미국    한국  중국
# 0  2.1  0.40  10
# 1  2.2  0.50  13
# 2  2.3  0.45  15

# %%
# 인덱스 값을 설정하는 방법
# 인덱스 명이 변경된 것처럼 보이지만, 인덱스의 오리지널은 결국 0부터 시작해서 1씩 증가하는 속성을 가지고 있다

df = pd.DataFrame({
    "미국": [2.1, 2.2, 2.3],     
    "한국": [0.4, 0.5, 0.45],     
    "중국": [10, 13, 15],
},index=[2000, 2010, 2020])

# %%
df
# Out:
#        미국    한국  중국
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
# 데이터프레임안에 인덱스를 조회하는 방법

df.index
# Out:
# Index([2000, 2010, 2020], dtype='int64')

# %%
# 인덱스의 값을 수정하는 방법

df.index = [2001, 2002, 2003]

# %%
df
# Out:
#        미국    한국  중국
# 2001  2.1  0.40  10
# 2002  2.2  0.50  13
# 2003  2.3  0.45  15

# %%
df.columns
# Out:
# Index(['일본', '필리핀', '러시아'], dtype='object')

# %%
# 필드명을 바꾸는 방법

df.columns = ["일본", "필리핀", "러시아"]

# %%
df
# Out:
#        일본   필리핀  러시아
# 2001  2.1  0.40   10
# 2002  2.2  0.50   13
# 2003  2.3  0.45   15

# %%
df.values
# Out:
# array([[ 2.1 ,  0.4 , 10.  ],
#        [ 2.2 ,  0.5 , 13.  ],
#        [ 2.3 ,  0.45, 15.  ]])

# %%
df = pd.DataFrame({
    "년도" : [2000, 2110, 2020],
    "미국": [2.1, 2.2, 2.3],     
    "한국": [0.4, 0.5, 0.45],     
    "중국": [10, 13, 15]
})

# %%
df
# Out:
#      년도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2110  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
# 시리즈를 인덱스로 바꿔서 보는 방법 (임시적)

df.set_index("년도")
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
# 시리즈를 인덱스로 바꾸는 방법

df = df.set_index("년도")

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
# 인덱스를 시리즈로 바꿔서 보는 방법 (임시적)

df.reset_index("년도")

# %%
# 인덱스를 시리즈로 바꾸는 방법

df = df.reset_index("년도")

# %%
df
# Out:
#      년도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2110  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
df = df.set_index("년도")

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.index.name = "연도"

# %%
df
# Out:
#        미국    한국  중국
# 연도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df = df.reset_index("연도")

# %%
df
# Out:
#      연도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2110  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
df = df.set_index("연도")
df
# Out:
#        미국    한국  중국
# 연도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.loc[2000]
# Out:
# 미국     2.1
# 한국     0.4
# 중국    10.0
# Name: 2000, dtype: float64

# %%
df.iloc[0]
# Out:
# 미국     2.1
# 한국     0.4
# 중국    10.0
# Name: 2000, dtype: float64

# %%
type(df.loc[2000])
# Out:
# pandas.core.series.Series

# %%
df["미국"]
# Out:
# 연도
# 2000    2.1
# 2110    2.2
# 2020    2.3
# Name: 미국, dtype: float64

# %%
type(df["미국"])
# Out:
# pandas.core.series.Series

# %%
print(df["미국"][2000]) # 열 방식
print(df.loc[2000]["미국"]) # 행 방식
print(df.iloc[0]["미국"]) # 행 방식2
# Out:
# 2.1
# 2.1
# 2.1

# %%
df = pd.DataFrame({
    "년도" : ["2000", "2110", "2020"],
    "미국": [2.1, 2.2, 2.3],     
    "한국": [0.4, 0.5, 0.45],     
    "중국": [10, 13, 15]
})

df
# Out:
#      년도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2110  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
df = df.set_index("년도")
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.loc["2000"]
# Out:
# 미국     2.1
# 한국     0.4
# 중국    10.0
# Name: 2000, dtype: float64

# %%
df.index
# Out:
# Index(['2000', '2110', '2020'], dtype='object', name='년도')

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df .columns
# Out:
# Index(['미국', '한국', '중국'], dtype='object')

# %%
# 새로운 시리즈를 추가하는 방식

df["일본"] = [1, 2, 3]

# %%
df
# Out:
#        미국    한국  중국  일본
# 년도
# 2000  2.1  0.40  10   1
# 2110  2.2  0.50  13   2
# 2020  2.3  0.45  15   3

# %%
del df["일본"]

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.loc["2021"] = [1, 2, 3]

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15
# 2021  1.0  2.00   3

# %%
# 인덱스를 기반으로 한 행을 삭제해서 보는 방법

df.drop(["2021"])
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15
# 2021  1.0  2.00   3

# %%
df = df.drop(["2021"])

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2110  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df = df.reset_index("년도")

# %%
df
# Out:
#      년도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2110  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
# 로우데이터를 건드리지 않고 원하는 시리즈만 모아서 볼 수 있는 방법

df2 = df[["한국", "중국"]].copy()

# %%
df2
# Out:
#      한국  중국
# 0  0.40  10
# 1  0.50  13
# 2  0.45  15

# %%
df
# Out:
#      년도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2110  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
df2.columns
# Out:
# Index(['한국', '중국'], dtype='object')

# %%
df2.columns = ["브라질", "아르헨티나"]

# %%
df2
# Out:
#     브라질  아르헨티나
# 0  0.40     10
# 1  0.50     13
# 2  0.45     15

# %%
df2["년도"] = [2000, 2010, 2020]

# %%
df2
# Out:
#     브라질  아르헨티나    년도
# 0  0.40     10  2000
# 1  0.50     13  2010
# 2  0.45     15  2020

# %%
df2 = df2.set_index("년도")

# %%
df2
# Out:
#        브라질  아르헨티나
# 년도
# 2000  0.40     10
# 2010  0.50     13
# 2020  0.45     15
