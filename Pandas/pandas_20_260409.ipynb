# %%
# pandas 파일 로드

import pandas as pd

doc = pd.read_csv("00_data/olist_customers_dataset.csv", encoding="utf-8-sig")
doc.head()
# Out:
#                         customer_id  ... customer_state
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  ...             SP
# 1  18955e83d337fd6b2def6b18a428ac77  ...             SP
# 2  4e7b3e00288586ebd08712fdd0374a03  ...             SP
# 3  b2b6027bc5c5109e529d4dc6358b12c3  ...             SP
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  ...             SP
#
# [5 rows x 5 columns]

# %%
# 데이터 사이즈

doc.shape
# Out:
# (99441, 5)

# %%
# 데이터 상세명세서 확인

doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
# 데이터 필드명 및 컬럼목록

doc.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
# 데이터 인덱스 (측정기준값)

doc.index
# Out:
# RangeIndex(start=0, stop=99441, step=1)

# %%
# 데이터 5 numbers summary

doc.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
# 데이터 상위 5개 확인하기

doc.head()
# Out:
#                         customer_id  ... customer_state
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  ...             SP
# 1  18955e83d337fd6b2def6b18a428ac77  ...             SP
# 2  4e7b3e00288586ebd08712fdd0374a03  ...             SP
# 3  b2b6027bc5c5109e529d4dc6358b12c3  ...             SP
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  ...             SP
#
# [5 rows x 5 columns]

# %%
# 로우데이터에서 필요하다고 판판되는 컬럼만 별도로 추출해서 가져오기

doc2 = doc[["customer_zip_code_prefix", "customer_city", "customer_state"]].copy()
doc2
# Out:
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 3 columns]

# %%
# 현재 카피해온 데이터프레임 안에서 특정 조건에 해당되는 값만 추출해오기

doc3 = doc2[doc2["customer_city"] == "sao paulo"]
doc3.shape
# Out:
# (15540, 3)

# %%
# 특정 데이터프레임 내, 컬럼을 기준으로 값의 갯수 확인

doc2["customer_city"].value_counts()
# Out:
# customer_city
# sao paulo                   15540
# rio de janeiro               6882
# belo horizonte               2773
# brasilia                     2131
# curitiba                     1521
#                             ...
# olhos d'agua                    1
# pacotuba                        1
# sao sebastiao do paraiba        1
# benedito leite                  1
# campos verdes                   1
# Name: count, Length: 4119, dtype: int64

# %%
# 특정 데이터프레임 내, 그룹화 (그룹화의 대상 = 인덱스)

doc4 = doc2.groupby("customer_city").count()
doc4
# Out:
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2
# ...                                       ...             ...
# xinguara                                    9               9
# xique-xique                                 3               3
# zacarias                                    2               2
# ze doca                                     5               5
# zortea                                      2               2
#
# [4119 rows x 2 columns]

# %%
# 특정 데이터프레임 내 인덱스의 길이 확인

len(doc4.index)
doc4.shape
# Out:
# (4119, 2)

# %%
# 특정 데이터프레임 내 상위 5개 문서 조회

doc4.head()
# Out:
#                      customer_zip_code_prefix  customer_state
# customer_city
# abadia dos dourados                         3               3
# abadiania                                   1               1
# abaete                                     12              12
# abaetetuba                                 11              11
# abaiara                                     2               2

# %%
doc4 = doc.groupby("customer_city").count()
doc4
# Out:
#                      customer_id  ...  customer_state
# customer_city                     ...
# abadia dos dourados            3  ...               3
# abadiania                      1  ...               1
# abaete                        12  ...              12
# abaetetuba                    11  ...              11
# abaiara                        2  ...               2
# ...                          ...  ...             ...
# xinguara                       9  ...               9
# xique-xique                    3  ...               3
# zacarias                       2  ...               2
# ze doca                        5  ...               5
# zortea                         2  ...               2
#
# [4119 rows x 4 columns]

# %%
# 특정 데이터프레임 내 컬럼을 기준으로 정렬

# doc4["customer_id"].sort_values() # 기본적으로 오름차순 정렬
doc4["customer_id"].sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# agisse                1
# vieiras               1
# bertopolis            1
# abadiania             1
# xexeu                 1
# Name: customer_id, Length: 4119, dtype: int64

# %%
# N번째 데이터 조회

doc4["customer_id"].sort_values(ascending=False).head() #head()에 매개변수가 존재하지 않으면 기본적으로 top5만 찾아온다
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
# Name: customer_id, dtype: int64

# %%
doc4.head()
# Out:
#                      customer_id  ...  customer_state
# customer_city                     ...
# abadia dos dourados            3  ...               3
# abadiania                      1  ...               1
# abaete                        12  ...              12
# abaetetuba                    11  ...              11
# abaiara                        2  ...               2
#
# [5 rows x 4 columns]

# %%
# 특정 데이터프레임 내 인덱스를 새롭게 정의

doc4.set_index("customer_id")
# Out:
#              customer_unique_id  customer_zip_code_prefix  customer_state
# customer_id
# 3                             3                         3               3
# 1                             1                         1               1
# 12                           12                        12              12
# 11                           11                        11              11
# 2                             2                         2               2
# ...                         ...                       ...             ...
# 9                             9                         9               9
# 3                             3                         3               3
# 2                             2                         2               2
# 5                             5                         5               5
# 2                             2                         2               2
#
# [4119 rows x 3 columns]

# %%
doc.set_index("customer_city")
# Out:
#                                             customer_id  ... customer_state
# customer_city                                            ...
# franca                 06b8999e2fba1a1fbc88172c00ba8bc7  ...             SP
# sao bernardo do campo  18955e83d337fd6b2def6b18a428ac77  ...             SP
# sao paulo              4e7b3e00288586ebd08712fdd0374a03  ...             SP
# mogi das cruzes        b2b6027bc5c5109e529d4dc6358b12c3  ...             SP
# campinas               4f2d8ab171c80ec8364f7c12e35b23ad  ...             SP
# ...                                                 ...  ...            ...
# sao paulo              17ddf5dd5d51696bb3d7c6291687be6f  ...             SP
# taboao da serra        e7b71a9017aa05c9a7fd292d714858e8  ...             SP
# fortaleza              5e28dfe12db7fb50a4b2f691faecea5e  ...             CE
# canoas                 56b18e2166679b8a959d72dd06da27f9  ...             RS
# cotia                  274fa6071e5e17fe303b9748641082c8  ...             SP
# ...

# %%
# 데이터프레임 > 인덱스 내 정렬앷

doc.set_index("customer_city").sort_index()
# Out:
#                                           customer_id  ... customer_state
# customer_city                                          ...
# abadia dos dourados  a23e3f9a2b656b23b7e52075964b42cd  ...             MG
# abadia dos dourados  9e01f714a2b3b8962c222cf2b74c20dc  ...             MG
# abadia dos dourados  f11eb8f0b8b87510a93e3e1aa10b0ade  ...             MG
# abadiania            576d71ddb21b21763cfedce73b902180  ...             GO
# abaete               5e9e1ae42e02df93e9a591e86fd531a3  ...             MG
# ...                                               ...  ...            ...
# ze doca              1052e334b46dd1e9876946d6372a363e  ...             MA
# ze doca              d8b3ef6f73de33ae716e94d2478cc080  ...             MA
# ze doca              fc87e5c06780700952aa42998a22968f  ...             MA
# zortea               0a466d490a3c2fcc1e7177f4809ec7dd  ...             SC
# zortea               e046f992a304cc92e1b00d7fccdf1c42  ...             SC
#
# ...

# %%
doc2
# Out:
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 3 columns]

# %%
doc2["customer_state"].value_counts().shape
# Out:
# (27,)

# %%
# 특정 데이터프레임 안에서 인덱스 요소를 해제하고 원래 컬럼 자리로 이동

doc4 = doc4.reset_index()

# %%
doc4
# Out:
#             customer_city  ...  customer_state
# 0     abadia dos dourados  ...               3
# 1               abadiania  ...               1
# 2                  abaete  ...              12
# 3              abaetetuba  ...              11
# 4                 abaiara  ...               2
# ...                   ...  ...             ...
# 4114             xinguara  ...               9
# 4115          xique-xique  ...               3
# 4116             zacarias  ...               2
# 4117              ze doca  ...               5
# 4118               zortea  ...               2
#
# [4119 rows x 5 columns]

# %%
doc4[doc4["customer_id"] > 1000].shape
# Out:
# (9, 5)

# %%
doc4 = doc4.set_index("customer_city")
doc4
# Out:
#                      customer_id  ...  customer_state
# customer_city                     ...
# abadia dos dourados            3  ...               3
# abadiania                      1  ...               1
# abaete                        12  ...              12
# abaetetuba                    11  ...              11
# abaiara                        2  ...               2
# ...                          ...  ...             ...
# xinguara                       9  ...               9
# xique-xique                    3  ...               3
# zacarias                       2  ...               2
# ze doca                        5  ...               5
# zortea                         2  ...               2
#
# [4119 rows x 4 columns]

# %%
doc4[doc4["customer_id"] > 1000].index
# Out:
# Index(['belo horizonte', 'brasilia', 'campinas', 'curitiba', 'guarulhos',
#        'porto alegre', 'rio de janeiro', 'salvador', 'sao paulo'],
#       dtype='object', name='customer_city')

# %%
doc4 = doc4.reset_index()
doc4
# Out:
#             customer_city  ...  customer_state
# 0     abadia dos dourados  ...               3
# 1               abadiania  ...               1
# 2                  abaete  ...              12
# 3              abaetetuba  ...              11
# 4                 abaiara  ...               2
# ...                   ...  ...             ...
# 4114             xinguara  ...               9
# 4115          xique-xique  ...               3
# 4116             zacarias  ...               2
# 4117              ze doca  ...               5
# 4118               zortea  ...               2
#
# [4119 rows x 5 columns]

# %%
doc
# Out:
#                             customer_id  ... customer_state
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  ...             SP
# 1      18955e83d337fd6b2def6b18a428ac77  ...             SP
# 2      4e7b3e00288586ebd08712fdd0374a03  ...             SP
# 3      b2b6027bc5c5109e529d4dc6358b12c3  ...             SP
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  ...             SP
# ...                                 ...  ...            ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  ...             SP
# 99437  e7b71a9017aa05c9a7fd292d714858e8  ...             SP
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  ...             CE
# 99439  56b18e2166679b8a959d72dd06da27f9  ...             RS
# 99440  274fa6071e5e17fe303b9748641082c8  ...             SP
#
# [99441 rows x 5 columns]

# %%
# 특정 데이터프레임의 결측치 존재 여부 확인

# doc.isnull()
doc.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# 수집된 데이터를 기반으로 리스트로 변경하기

#doc.drop_duplicates(subset="customer_city", keep="first") # first: 중복 값중 최초값만 살림 , last : 중복 값중 최종값만 살림
doc.drop_duplicates(subset="customer_city", keep="first")["customer_city"].to_list()
# Out:
# ['franca',
#  'sao bernardo do campo',
#  'sao paulo',
#  'mogi das cruzes',
#  'campinas',
#  'jaragua do sul',
#  'timoteo',
#  'curitiba',
#  'belo horizonte',
#  'montes claros',
#  'rio de janeiro',
#  'lencois paulista',
#  'caxias do sul',
#  'piracicaba',
#  'guarulhos',
#  'pacaja',
#  'florianopolis',
#  'aparecida de goiania',
#  'santo andre',
#  'goiania',
#  'cachoeiro de itapemirim',
#  'sao jose dos campos',
#  'sao roque',
#  'camacari',
#  'resende',
#  'sumare',
#  'novo hamburgo',
#  'sao luis',
#  'sao jose',
#  'santa barbara',
#  'ribeirao preto',
#  'ituiutaba',
#  'taquarituba',
#  'sao jose dos pinhais',
#  'barrinha',
#  'parati',
#  'dourados',
#  'trindade',
#  'cascavel',
#  'fortaleza',
#  'brasilia',
#  'pelotas',
#  'porto alegre',
#  'salto',
#  'jundiai',
#  'cacapava',
#  'sao vicente',
#  'uberlandia',
#  'botelhos',
#  'sao goncalo',
#  'araucaria',
#  'nova iguacu',
#  'areia branca',
#  'campos dos goytacazes',
#  'sao carlos',
#  'itajuba',
# ...

# %%
# 피봇테이블 = 기존 데이터에서 추가적으로 필터링을 해서 값을 찾아오는 것

import pandas as pd
doc_covid = pd.read_csv("COVID-19-master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv", encoding="utf-8-sig")
doc_covid.head()
# Out:
#       FIPS     Admin2  ... Active                   Combined_Key
# 0  45001.0  Abbeville  ...      4  Abbeville, South Carolina, US
# 1  22001.0     Acadia  ...     46          Acadia, Louisiana, US
# 2  51001.0   Accomack  ...      7         Accomack, Virginia, US
# 3  16001.0        Ada  ...    192                 Ada, Idaho, US
# 4  19001.0      Adair  ...      1                Adair, Iowa, US
#
# [5 rows x 12 columns]

# %%
import pandas as pd

doc_covid3 = pd.pivot_table(doc_covid, 
                index=["Country_Region"], 
                values=["Confirmed", "Deaths"], 
                aggfunc={"Confirmed": "sum", "Deaths": "mean"}, 
                fill_value=0,
                margins=True,
                margins_name="Total"
            ) 
# fill_value=0 : 결측치가 있다면 그 값을 0으로 만들어

doc_covid3.head()
# Out:
#                 Confirmed  Deaths
# Country_Region
# Afghanistan           192     4.0
# Albania               259    15.0
# Algeria               847    58.0
# Andorra               390    14.0
# Angola                  8     2.0

# %%
doc_covid3[doc_covid3.index == "Total"]
# Out:
#                 Confirmed     Deaths
# Country_Region
# Total              938959  20.477002

# %%
doc_covid3.style.format({
    "Confirmed": "{:,}",
    "Deaths": "{:..2f}"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\IPython\core\formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\style.py:405, in Styler._repr_html_(self)
#     400 """
#     401 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     402 default if an object is returned at the end of a cell.
#     403 """
#     404 if get_option("styler.render.repr") == "html":
# --> 405     return self.to_html()
#     406 return None
#
# ...
