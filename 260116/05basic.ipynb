# %%
# 조건문 : 값을 출력하기 위해서, A / B에 따라서 다른 값을 출력해야할 때가 있음
# 1) if 조건문 : A라면~ / B라면~ (단일조건)
# 2) if else문 : A라면, 만약 A가 아니라면 (양자택일)
# 3) if elif else문 : A라면, B라면, C라면 (다중조건)
# > else문 : 무조건 if, elif 보다 먼저 나올 수 없다!!!
# > else문 : (필수조건, 비필수조건)
# > 조건문 : 문법 (조건식 + 실행문)
# 조건문 > 조건식 > 비교연산자 | 논리연산자 
# 중첩 if 조건문


# for문 처럼 반드시 밑에 나오는것들은 if보다 들여쓰기가 되있어야한다
"""
if 조건식 :
    실행문

if 조건1 and 조건2 :
    실행문

if not 조건 : -> 조건식의 값이 부정(False) 인 경우에 한해서 실행문을 실행시켜야 하는 경우
    실행문

if 조건식1 :
    실행문2
else :
    if 조건식2 :
        실행문2
        else :
            실행문3
"""

# %%
age = input("당신의 나이는?")
age_digit = int(age)

if age_digit >= 19 :
    print("당신은 성인입니다")
# Out:
# 당신의 나이는? 22
# 당신은 성인입니다

# %%
age1 = input("흥민이의 나이는?")
age_digit1 = int(age1)

age2 = input("강인이의 나이는?")
age_digit2 = int(age2)

if age_digit >= 19 and age_digit2 >= 19 :
    print("두 사람 모두 성인입니다")
# Out:
# 흥민이의 나이는? 28
# 강인이의 나이는? 22
# 두 사람 모두 성인입니다

# %%
cash = int(input("현재 가지고 있는 돈은 얼마인가요?"))

if cash > 100000 :
    print("Go to Fine Buffet")
else :
    if cash > 50000 :
        print("Go to Korea restaurant")
    else :
        print("Go to Home")

# %%
cash = int(input("현재 가지고 있는 돈은 얼마인가요?"))

if cash > 100000 :
    print("레스토랑")
else :
    if cash > 50000 :
        if cash > 70000 :
            print("TGIF")
        elif cash > 60000
             print("밥집")
        else :
             print("분식집")
    else :
        print("집")

# %%
# 사용자로부터 값을 받아서 짝수인지, 홀수인지 판단 후 짝수라면, "짝수입니다." 출력, "홀수입니다" 출력

"""
number = int(input("당신의 값은 몇인가요?))

if number = 2 :
    print("짝수입니다.")
else :
    if number = 3 :
        print(("홀수입니다.")
"""


              
number = int(input("숫자를 입력하세요"))

if number % 2 == 1 :
    print(("해당 숫자는 홀수입니다.")

else :
    print(("해당 숫자는 짝수입니다.")

# %%
# 사용자에서 3개의 숫자를 입력받은 후 그 중 가장 작은 숫자를 출력하세요

"""
number = int(input("3개의 숫자를 입력하세요"))

if number 

number.reverse()
"""


num01 = int(input("첫번째 숫자"))
num02 = int(input("두번째 숫자"))
num03 = int(input("세번째 숫자"))

if num01 <= num02 and num01 <= num03 :
    print(num01)
elif num02 <= num01 and num02 <= num03 :
    print(num02)
elif num03 <= num01 and num03 <= num02 :
    print(num03)

# %%
# 사용자에게 주민등록번호를 입력받으세요. 그리고 해당 사용자가 몇년도에 출생했는지 출력해주세요

"""
num = int(input("930506")
print.num[0,1]
"""

          
private_number = input("주민등록번호는?")
#140116-123456

result = private_number[0:2]
print(f"{result}년생 입니다")
